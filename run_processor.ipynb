# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

from processor import Processor

# %%
p = Processor(yt_url="https://www.youtube.com/watch?v=NzXGXMgdGOI", start=23, end=40, focus="bass")

# %%
p.download()
# Out:
# MoviePy - Writing audio in ./temp/current_audio.mp3
# MoviePy - Done.

# %%
p.audio_file = "./temp/current_audio.mp3"
p.separate_audio()

# %%
p.focus = "bass"

# %%
p.process_audio(window_size=50, threshold_factor=1.9)
p.plot_audio()

# %%
p.save_sample_video()
# Out:
# Moviepy - Building video ./temp/output_video.mp4.
# MoviePy - Writing audio in output_videoTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video ./temp/output_video.mp4
# Moviepy - Done !
# Moviepy - video ready ./temp/output_video.mp4

# %%
p.save_separated_audio()
# Out:
# drums torch.Size([2, 8522766])
# bass torch.Size([2, 8522766])
# other torch.Size([2, 8522766])
# vocals torch.Size([2, 8522766])
